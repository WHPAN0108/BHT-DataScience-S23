# %%
from PIL import Image
import numpy as np

im = np.array(Image.open('data/lena.jpg').convert('L'))

# %%
Image.fromarray(im)
# Out:
# <PIL.Image.Image image mode=L size=400x225>

# %%
print(im.shape)
# Out:
# (225, 400)

# %%
print(np.matrix(im))
# Out:
# [[ 80  80  79 ...  46  52  59]
#  [ 83  82  78 ...  44  47  53]
#  [ 82  81  78 ...  43  46  52]
#  ...
#  [ 89  87  91 ...  88  87  93]
#  [ 87  85  90 ...  91  87  91]
#  [ 88  87  85 ... 100  94  99]]

# %% [markdown]
# White :255
# Black :0

# %%
Image.fromarray((im>50))
# Out:
# <PIL.Image.Image image mode=1 size=400x225>

# %%
Image.fromarray((im>50)*im)
# Out:
# <PIL.Image.Image image mode=L size=400x225>

# %%
Image.fromarray(np.transpose(im))
# Out:
# <PIL.Image.Image image mode=L size=225x400>

# %%
A=-np.eye(400,225, dtype=int)
Image.fromarray(np.matmul(im,A))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/project/teaching-DS/.venv/lib/python3.10/site-packages/PIL/Image.py:3089, in fromarray(obj, mode)
#    3088 try:
# -> 3089     mode, rawmode = _fromarray_typemap[typekey]
#    3090 except KeyError as e:
#
# KeyError: ((1, 1), '<i8')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 A=-np.eye(400,225, dtype=int)
# ----> 2 Image.fromarray(np.matmul(im,A))
#
# File ~/project/teaching-DS/.venv/lib/python3.10/site-packages/PIL/Image.py:3092, in fromarray(obj, mode)
#    3090     except KeyError as e:
#    3091         msg = "Cannot handle this data type: %s, %s" % typekey
# -> 3092         raise TypeError(msg) from e
#    3093 else:
#    3094     rawmode = mode
#
# ...
